# %% [markdown]
# В файле question_10.csv часовые данные по объемам торгов акциями Газпрома (реальные данные). Проверить:
#
# Есть ли сезонность в данных?
# Каков период сезонности ?
# Построить прогноз данных на период сезонности методом сезонной модели Хольта-Уинтерса
# В каких наблюдениях сезонного эффекта наибольший и наименьший объем сделок? По этим номерам можно узнать во сколько по времени это происходит, если знать, что данные начинаются с 11:00. Произнесите правильно на русском языке как будете докладывать начальству на работе (зависит от типа модели) про наибольший и наименьший объем.
