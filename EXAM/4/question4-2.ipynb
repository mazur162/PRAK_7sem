# %% [markdown]
# #Построение кросс-корреляционной функции между рядами x, y

# %%
acf(data$x,main = "ACF of x_t process",lwd = 5,col = "blue")
# Out:
# Plot with title “ACF of x_t process”

# %%
pacf(data$x,main = "PACF of x_t process",lwd = 5,col = "blue")
# Out:
# Plot with title “PACF of x_t process”

# %%
acf(data$y,main = "ACF of y_t process",lwd = 5,col = "blue")
# Out:
# Plot with title “ACF of y_t process”

# %%
pacf(data$y,main = "PACF of y_t process",lwd = 5,col = "blue")
# Out:
# Plot with title “PACF of y_t process”

# %% [markdown]
# #Определение задержки между рядами x, y

# %%
data <-read.csv("/content/question_4.csv")

# %%
head(data)
# Out:
#   x           y
# 1  0.76113745  0.09121127
# 2  0.81808598  0.16027269
# 3 -1.57177767 -1.84896909
# 4  0.40975434  1.90011466
# 5 -1.04338995  0.67390720
# 6 -0.05926706 -1.11116425

# %%
length(data$x)
# Out:
# [1] 291

# %%
ccf(data$x, data$y, lag.max= 10 ,type ="correlation", main = "Cross-correlation. x vs y", lwd = 5, col = "blue")
# Out:
# Plot with title “Cross-correlation. x vs y”

# %%
d <- 9
ccf(c(data$x)[1: {291-d}], c(data$y)[d + 1: 291] ,lwd = 5, main = "Cross-correlation of x_t and y_t",col = "blue")
# Out:
# Plot with title “Cross-correlation of x_t and y_t”

# %% [markdown]
# d = 9
# x опережает y

# %% [markdown]
# # лекция

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
